# %%
import pickle
import pandas as pd
import numpy as np
import os

# =====================================================================
# 0. LOAD PREVIOUSLY SAVED DICTS
# =====================================================================

load_dir = "./cfpr_evaluation_dicts"

with open(os.path.join(load_dir, "category_results_mape.pkl"), "rb") as f:
    category_results_mape = pickle.load(f)

with open(os.path.join(load_dir, "category_residual_results.pkl"), "rb") as f:
    category_residual_results = pickle.load(f)

print("✅ Loaded evaluation dictionaries")

# =====================================================================
# 1. BUILD UNIFIED TABLES FOR EACH CATEGORY
# =====================================================================

combined_summaries = {}

for category in category_results_mape.keys():
    if category not in category_residual_results:
        continue

    # --- Get per-model mean MAPE for this category ---
    mape_series = category_results_mape[category].mean().rename("MAPE")

    # --- Get YoY residuals (already top-10 ranked, but we’ll re-use full values) ---
    yoy_series = category_residual_results[category].rename("YoY_Residual")

    # --- Combine both into one DataFrame ---
    combo = pd.concat([mape_series, yoy_series], axis=1).dropna()

    # --- Compute ranks explicitly and clearly ---
    combo["Rank_MAPE"] = combo["MAPE"].rank(method="min", ascending=True)
    combo["Rank_Residual"] = combo["YoY_Residual"].abs().rank(method="min", ascending=True)
    combo["Rank_Mean"] = combo[["Rank_MAPE", "Rank_Residual"]].mean(axis=1)

    # --- Sort by combined rank ---
    combo = combo.sort_values("Rank_Mean")

    # Store in dictionary
    combined_summaries[category] = combo

# =====================================================================
# 2. PRINT TOP MODELS PER CATEGORY
# =====================================================================

print("\n===== Agreement between MAPE & YoY Residuals (Corrected Ranks) =====")

for category, df_cat in combined_summaries.items():
    print(f"\n{category}")
    print(df_cat.head(5).round(3))
# Out:
# ✅ Loaded evaluation dictionaries
#
# ===== Agreement between MAPE & YoY Residuals (Corrected Ranks) =====
#
# Food
#                                                      MAPE  YoY_Residual  \
# ag_local_TemporalFusionTransformerModel             0.480         0.246
# ag_global_all_SimpleFeedForwardModel_exp5_geopo...  0.921         0.568
# ag_local_AutoARIMAModel                             0.743         0.596
# ag_global_all_ChronosModel                          1.323        -0.459
# ag_global_all_SimpleFeedForwardModel_exp1_human_    0.928         0.804
#
#                                                     Rank_MAPE  Rank_Residual  \
# ag_local_TemporalFusionTransformerModel                   1.0            1.0
# ag_global_all_SimpleFeedForwardModel_exp5_geopo...        3.0            3.0
# ag_local_AutoARIMAModel                                   2.0            4.0
# ag_global_all_ChronosModel                                7.0            2.0
# ag_global_all_SimpleFeedForwardModel_exp1_human_          4.0            6.0
#
#                                                     Rank_Mean
# ag_local_TemporalFusionTransformerModel                   1.0
# ag_global_all_SimpleFeedForwardModel_exp5_geopo...        3.0
# ag_local_AutoARIMAModel                                   3.0
# ag_global_all_ChronosModel                                4.5
# ag_global_all_SimpleFeedForwardModel_exp1_human_          5.0
#
# Meat
#                                                MAPE  YoY_Residual  Rank_MAPE  \
# ag_local_DeepARModel                          0.859        -0.269        1.0
# claude-3-5-sonnet-20240620_report_False       1.184        -0.196        3.0
# ag_global_all_TemporalFusionTransformerModel  1.037        -0.348        2.0
# ag_local_SimpleFeedForwardModel               1.371        -0.257        4.0
# ag_global_all_ChronosModel                    1.462        -0.186        7.0
#
#                                               Rank_Residual  Rank_Mean
# ag_local_DeepARModel                                    6.0        3.5
# claude-3-5-sonnet-20240620_report_False                 4.0        3.5
# ag_global_all_TemporalFusionTransformerModel            7.0        4.5
# ag_local_SimpleFeedForwardModel                         5.0        4.5
# ag_global_all_ChronosModel                              3.0        5.0
#
# Fish, seafood and other marine products
#                                                      MAPE  YoY_Residual  \
# ag_local_DeepARModel                                0.409        -0.081
# ag_local_ChronosModel                               0.500        -0.093
# ag_global_all_DeepARModel_exp1_llm_                 0.636        -0.335
# ag_global_all_TemporalFusionTransformerModel_ex...  0.620        -0.355
# ag_global_all_TemporalFusionTransformerModel_ex...  0.733         0.219
#
#                                                     Rank_MAPE  Rank_Residual  \
# ag_local_DeepARModel                                      1.0            2.0
# ag_local_ChronosModel                                     2.0            3.0
# ag_global_all_DeepARModel_exp1_llm_                       4.0            6.0
# ag_global_all_TemporalFusionTransformerModel_ex...        3.0            7.0
# ag_global_all_TemporalFusionTransformerModel_ex...        6.0            4.0
#
#                                                     Rank_Mean
# ag_local_DeepARModel                                      1.5
# ag_local_ChronosModel                                     2.5
# ag_global_all_DeepARModel_exp1_llm_                       5.0
# ag_global_all_TemporalFusionTransformerModel_ex...        5.0
# ag_global_all_TemporalFusionTransformerModel_ex...        5.0
#
# Dairy products and eggs
#                                                      MAPE  YoY_Residual  \
# ag_local_AutoETSModel                               0.340        -0.046
# ag_local_AutoARIMAModel                             0.397         0.103
# ag_global_all_DeepARModel                           0.373        -0.292
# ag_global_all_SimpleFeedForwardModel_exp5_geopo...  0.583         0.525
# ag_global_all_ChronosModel                          0.843         0.861
#
#                                                     Rank_MAPE  Rank_Residual  \
# ag_local_AutoETSModel                                     1.0            1.0
# ag_local_AutoARIMAModel                                   3.0            2.0
# ag_global_all_DeepARModel                                 2.0            4.0
# ag_global_all_SimpleFeedForwardModel_exp5_geopo...        4.0            5.0
# ag_global_all_ChronosModel                                5.0            7.0
#
#                                                     Rank_Mean
# ag_local_AutoETSModel                                     1.0
# ag_local_AutoARIMAModel                                   2.5
# ag_global_all_DeepARModel                                 3.0
# ag_global_all_SimpleFeedForwardModel_exp5_geopo...        4.5
# ag_global_all_ChronosModel                                6.0
#
# Bakery and cereal products (excluding baby food)
#                                           MAPE  YoY_Residual  Rank_MAPE  \
# gemini-1.5-pro_report_True               0.444        -0.017        2.0
# claude-3-5-sonnet-20240620_report_False  0.526         0.051        3.0
# gemini-1.5-pro_report_False              0.425        -0.152        1.0
# claude-3-5-sonnet-20240620_report_True   0.532         0.084        4.0
# gpt-4o_report_True                       0.544        -0.219        5.0
#
#                                          Rank_Residual  Rank_Mean
# gemini-1.5-pro_report_True                         1.0        1.5
# claude-3-5-sonnet-20240620_report_False            2.0        2.5
# gemini-1.5-pro_report_False                        4.0        2.5
# claude-3-5-sonnet-20240620_report_True             3.0        3.5
# gpt-4o_report_True                                 6.0        5.5
#
# Fruit, fruit preparations and nuts
#                                                      MAPE  YoY_Residual  \
# ag_local_TemporalFusionTransformerModel             0.637         0.040
# ag_global_all_SimpleFeedForwardModel                0.734        -0.229
# ag_global_all_SimpleFeedForwardModel_exp1_llm_      0.724         0.253
# ag_global_all_SimpleFeedForwardModel_exp5_climate_  0.929        -0.218
# ag_global_all_SimpleFeedForwardModel_exp5_manuf...  0.940         1.041
#
#                                                     Rank_MAPE  Rank_Residual  \
# ag_local_TemporalFusionTransformerModel                   1.0            1.0
# ag_global_all_SimpleFeedForwardModel                      3.0            3.0
# ag_global_all_SimpleFeedForwardModel_exp1_llm_            2.0            4.0
# ag_global_all_SimpleFeedForwardModel_exp5_climate_        4.0            2.0
# ag_global_all_SimpleFeedForwardModel_exp5_manuf...        5.0            7.0
#
#                                                     Rank_Mean
# ag_local_TemporalFusionTransformerModel                   1.0
# ag_global_all_SimpleFeedForwardModel                      3.0
# ag_global_all_SimpleFeedForwardModel_exp1_llm_            3.0
# ag_global_all_SimpleFeedForwardModel_exp5_climate_        3.0
# ag_global_all_SimpleFeedForwardModel_exp5_manuf...        6.0
#
# Vegetables and vegetable preparations
#                                           MAPE  YoY_Residual  Rank_MAPE  \
# claude-3-5-sonnet-20240620_report_False  1.345        -0.278        2.0
# ag_global_all_DLinearModel               1.765         0.171        6.0
# ag_local_DLinearModel                    1.508        -0.546        3.0
# ag_local_TemporalFusionTransformerModel  1.243        -0.867        1.0
# claude-3-5-sonnet-20240620_report_True   1.762         0.821        5.0
#
#                                          Rank_Residual  Rank_Mean
# claude-3-5-sonnet-20240620_report_False            2.0        2.0
# ag_global_all_DLinearModel                         1.0        3.5
# ag_local_DLinearModel                              5.0        4.0
# ag_local_TemporalFusionTransformerModel            8.0        4.5
# claude-3-5-sonnet-20240620_report_True             7.0        6.0
#
# Other food products and non-alcoholic beverages
#                                                      MAPE  YoY_Residual  \
# ag_global_all_TemporalFusionTransformerModel_ex...  1.205        -0.114
# ag_global_all_TemporalFusionTransformerModel        1.266        -0.312
# ag_local_AutoETSModel                               1.435         0.168
# ag_global_all_SimpleFeedForwardModel_exp5_climate_  1.937         0.423
# ag_global_all_TemporalFusionTransformerModel_ex...  1.121         0.893
#
#                                                     Rank_MAPE  Rank_Residual  \
# ag_global_all_TemporalFusionTransformerModel_ex...        2.0            1.0
# ag_global_all_TemporalFusionTransformerModel              3.0            3.0
# ag_local_AutoETSModel                                     4.0            2.0
# ag_global_all_SimpleFeedForwardModel_exp5_climate_        6.0            4.0
# ag_global_all_TemporalFusionTransformerModel_ex...        1.0            9.0
#
#                                                     Rank_Mean
# ag_global_all_TemporalFusionTransformerModel_ex...        1.5
# ag_global_all_TemporalFusionTransformerModel              3.0
# ag_local_AutoETSModel                                     3.0
# ag_global_all_SimpleFeedForwardModel_exp5_climate_        5.0
# ag_global_all_TemporalFusionTransformerModel_ex...        5.0
#
# Food purchased from restaurants
#                                                      MAPE  YoY_Residual  \
# ag_global_all_DeepARModel                           2.462         0.001
# ag_local_DLinearModel                               2.613         0.885
# ag_local_DeepARModel                                3.002        -0.610
# ag_global_all_SimpleFeedForwardModel_exp5_geopo...  1.907         1.592
# ag_global_cpi_with_covariates_TemporalFusionTra...  2.794        -1.477
#
#                                                     Rank_MAPE  Rank_Residual  \
# ag_global_all_DeepARModel                                 2.0            1.0
# ag_local_DLinearModel                                     3.0            4.0
# ag_local_DeepARModel                                      6.0            3.0
# ag_global_all_SimpleFeedForwardModel_exp5_geopo...        1.0            9.0
# ag_global_cpi_with_covariates_TemporalFusionTra...        4.0            7.0
#
#                                                     Rank_Mean
# ag_global_all_DeepARModel                                 1.5
# ag_local_DLinearModel                                     3.5
# ag_local_DeepARModel                                      4.5
# ag_global_all_SimpleFeedForwardModel_exp5_geopo...        5.0
# ag_global_cpi_with_covariates_TemporalFusionTra...        5.5

# %%
# =====================================================================
# 3. GLOBAL ANALYSIS: WHICH MODELS ARE CONSISTENTLY BEST?
# =====================================================================

# Combine all category-level tables into one DataFrame
stacked = pd.concat(
    [df.assign(category=cat) for cat, df in combined_summaries.items()],
    axis=0
).reset_index().rename(columns={"index": "model"})

# --- Compute overall statistics per model ---
# Lower MAPE and lower abs(Residual) = better
overall_summary = (
    stacked.groupby("model")[["MAPE", "YoY_Residual", "Rank_Mean"]]
    .agg({
        "MAPE": "mean",
        "YoY_Residual": lambda x: np.mean(np.abs(x)),
        "Rank_Mean": "mean"
    })
    .sort_values("Rank_Mean")
)

print("\n===== Global Model Ranking (Lower = Better Across All Food Categories) =====")
display(overall_summary.round(3))

# =====================================================================
# 4. DETERMINE WHICH MODELS TO RETAIN
# =====================================================================

# --- Core set: top N models overall ---
N = 5  # you can adjust this number easily
top_models = overall_summary.head(N).index.tolist()

print(f"\n🧠 Suggested Core Models to Retain ({N} models):")
for i, m in enumerate(top_models, start=1):
    print(f"{i}. {m}")

# --- Also identify coverage: how many categories each model appears in the top-3 ---
coverage = (
    stacked.groupby(["category", "model"])["Rank_Mean"]
    .mean()
    .reset_index()
    .sort_values("Rank_Mean")
)

coverage["Top3"] = coverage.groupby("category")["Rank_Mean"].rank(method="min") <= 3

model_coverage = coverage.groupby("model")["Top3"].sum().sort_values(ascending=False)

print("\n📊 Model Coverage — Number of Categories where Model is Top-3:")
display(model_coverage.head(10))
# Out:
# ===== Global Model Ranking (Lower = Better Across All Food Categories) =====
#                                                      MAPE  YoY_Residual  \
# model
# gemini-1.5-pro_report_True                          0.444         0.017
# ag_global_all_TemporalFusionTransformerModel_ex...  1.205         0.114
# gemini-1.5-pro_report_False                         0.425         0.152
# claude-3-5-sonnet-20240620_report_False             1.018         0.175
# ag_local_AutoARIMAModel                             0.570         0.350
# ag_local_TemporalFusionTransformerModel             0.804         0.377
# ag_global_all_SimpleFeedForwardModel_exp5_climate_  1.559         0.260
# ag_local_DeepARModel                                1.569         0.487
# claude-3-5-sonnet-20240620_report_True              1.147         0.453
# ag_global_all_DeepARModel_exp1_llm_                 0.636         0.335
# ag_global_all_TemporalFusionTransformerModel_ex...  0.870         0.624
# ag_global_all_ChronosModel                          1.210         0.502
# ag_global_all_SimpleFeedForwardModel                1.287         0.442
# ag_global_all_SimpleFeedForwardModel_exp5_geopo...  1.249         0.761
# ag_local_AutoETSModel                               1.105         0.567
# ag_global_all_TemporalFusionTransformerModel_ex...  1.071         0.562
# ag_global_all_TemporalFusionTransformerModel        0.985         0.534
# ag_global_all_DeepARModel                           1.603         0.642
# gpt-4o_report_True                                  0.544         0.219
# ag_local_DLinearModel                               1.810         0.595
# ag_global_all_SimpleFeedForwardModel_exp1_llm_      1.332         0.691
# ag_global_all_SimpleFeedForwardModel_exp5_manuf...  0.940         1.041
# ag_global_all_DLinearModel                          2.787         0.832
# ag_global_cpi_with_covariates_TemporalFusionTra...  2.184         0.627
# ag_global_cpi_with_covariates_TemporalFusionTra...  2.823         0.594
# gpt-4o_report_False                                 0.602         0.191
# ag_global_all_DeepARModel_exp5_climate_             3.016         1.412
# ag_local_SimpleFeedForwardModel                     1.286         0.806
# ag_local_ChronosModel                               1.187         0.460
# ag_global_all_PatchTSTModel                         2.684         0.604
# ag_global_all_SimpleFeedForwardModel_exp1_human_    1.185         0.764
# ag_global_cpi_with_covariates_TemporalFusionTra...  0.575         0.439
# ag_local_NaiveModel                                 1.958         0.794
# ag_global_all_DeepARModel_exp1_human_               2.873         1.633
# ag_local_PatchTSTModel                              0.982         1.109
# ag_global_all_TemporalFusionTransformerModel_ex...  1.760         1.387
#
#                                                     Rank_Mean
# model
# gemini-1.5-pro_report_True                              1.500
# ag_global_all_TemporalFusionTransformerModel_ex...      1.500
# gemini-1.5-pro_report_False                             2.500
# claude-3-5-sonnet-20240620_report_False                 2.667
# ag_local_AutoARIMAModel                                 2.750
# ag_local_TemporalFusionTransformerModel                 3.875
# ag_global_all_SimpleFeedForwardModel_exp5_climate_      4.333
# ag_local_DeepARModel                                    4.625
# claude-3-5-sonnet-20240620_report_True                  4.750
# ag_global_all_DeepARModel_exp1_llm_                     5.000
# ag_global_all_TemporalFusionTransformerModel_ex...      5.000
# ag_global_all_ChronosModel                              5.167
# ag_global_all_SimpleFeedForwardModel                    5.167
# ag_global_all_SimpleFeedForwardModel_exp5_geopo...      5.300
# ag_local_AutoETSModel                                   5.500
# ag_global_all_TemporalFusionTransformerModel_ex...      5.500
# ag_global_all_TemporalFusionTransformerModel            5.500
# ag_global_all_DeepARModel                               5.500
# gpt-4o_report_True                                      5.500
# ag_local_DLinearModel                                   5.600
# ag_global_all_SimpleFeedForwardModel_exp1_llm_          5.750
# ag_global_all_SimpleFeedForwardModel_exp5_manuf...      6.000
# ag_global_all_DLinearModel                              6.000
# ag_global_cpi_with_covariates_TemporalFusionTra...      6.250
# ag_global_cpi_with_covariates_TemporalFusionTra...      6.250
# gpt-4o_report_False                                     6.500
# ag_global_all_DeepARModel_exp5_climate_                 6.500
# ag_local_SimpleFeedForwardModel                         6.750
# ag_local_ChronosModel                                   7.125
# ag_global_all_PatchTSTModel                             7.333
# ag_global_all_SimpleFeedForwardModel_exp1_human_        7.375
# ag_global_cpi_with_covariates_TemporalFusionTra...      7.500
# ag_local_NaiveModel                                     7.500
# ag_global_all_DeepARModel_exp1_human_                   7.500
# ag_local_PatchTSTModel                                  8.000
# ag_global_all_TemporalFusionTransformerModel_ex...      8.500
# 🧠 Suggested Core Models to Retain (5 models):
# 1. gemini-1.5-pro_report_True
# 2. ag_global_all_TemporalFusionTransformerModel_exp1_llm_
# 3. gemini-1.5-pro_report_False
# 4. claude-3-5-sonnet-20240620_report_False
# 5. ag_local_AutoARIMAModel
#
# 📊 Model Coverage — Number of Categories where Model is Top-3:
# model
# ag_local_DeepARModel                            3
# claude-3-5-sonnet-20240620_report_False         3
# ag_local_DLinearModel                           2
# ag_local_AutoETSModel                           2
# ag_local_AutoARIMAModel                         2
# ag_local_TemporalFusionTransformerModel         2
# ag_global_all_TemporalFusionTransformerModel    2
# ag_global_all_DeepARModel                       2
# ag_global_all_SimpleFeedForwardModel            1
# gemini-1.5-pro_report_True                      1
# Name: Top3, dtype: int64

# %%
# =====================================================================
# 5️⃣ SAVE CROSS-ANALYSIS RESULTS
# =====================================================================

import pickle

save_dir = "./cfpr_evaluation_dicts"
os.makedirs(save_dir, exist_ok=True)

# --- 1️⃣ Save detailed combined per-category tables
with open(os.path.join(save_dir, "combined_summaries.pkl"), "wb") as f:
    pickle.dump(combined_summaries, f)

# --- 2️⃣ Save overall summary table
overall_summary.reset_index().to_csv(
    os.path.join(save_dir, "overall_summary_cross.csv"), index=False
)

# --- 3️⃣ Save model coverage info
model_coverage.to_csv(os.path.join(save_dir, "model_coverage_cross.csv"))

print("✅ Saved cross-analysis outputs:")
print(f"• combined_summaries.pkl — detailed category-level comparison (MAPE + YoY residual + ranks)")
print(f"• overall_summary_cross.csv — global summary of model performance")
print(f"• model_coverage_cross.csv — number of categories where each model ranked top-3\n")

# --- Optional confirmation preview ---
print("\n===== Top 10 Models by Combined Rank =====")
print(overall_summary.head(10).round(3))

print("\n===== Model Coverage Summary (Top 10) =====")
print(model_coverage.head(10))
# Out:
# ✅ Saved cross-analysis outputs:
# • combined_summaries.pkl — detailed category-level comparison (MAPE + YoY residual + ranks)
# • overall_summary_cross.csv — global summary of model performance
# • model_coverage_cross.csv — number of categories where each model ranked top-3
#
#
# ===== Top 10 Models by Combined Rank =====
#                                                      MAPE  YoY_Residual  \
# model
# gemini-1.5-pro_report_True                          0.444         0.017
# ag_global_all_TemporalFusionTransformerModel_ex...  1.205         0.114
# gemini-1.5-pro_report_False                         0.425         0.152
# claude-3-5-sonnet-20240620_report_False             1.018         0.175
# ag_local_AutoARIMAModel                             0.570         0.350
# ag_local_TemporalFusionTransformerModel             0.804         0.377
# ag_global_all_SimpleFeedForwardModel_exp5_climate_  1.559         0.260
# ag_local_DeepARModel                                1.569         0.487
# claude-3-5-sonnet-20240620_report_True              1.147         0.453
# ag_global_all_DeepARModel_exp1_llm_                 0.636         0.335
#
#                                                     Rank_Mean
# model
# gemini-1.5-pro_report_True                              1.500
# ag_global_all_TemporalFusionTransformerModel_ex...      1.500
# gemini-1.5-pro_report_False                             2.500
# claude-3-5-sonnet-20240620_report_False                 2.667
# ag_local_AutoARIMAModel                                 2.750
# ag_local_TemporalFusionTransformerModel                 3.875
# ag_global_all_SimpleFeedForwardModel_exp5_climate_      4.333
# ag_local_DeepARModel                                    4.625
# claude-3-5-sonnet-20240620_report_True                  4.750
# ag_global_all_DeepARModel_exp1_llm_                     5.000
#
# ===== Model Coverage Summary (Top 10) =====
# model
# ag_local_DeepARModel                            3
# claude-3-5-sonnet-20240620_report_False         3
# ag_local_DLinearModel                           2
# ag_local_AutoETSModel                           2
# ag_local_AutoARIMAModel                         2
# ag_local_TemporalFusionTransformerModel         2
# ag_global_all_TemporalFusionTransformerModel    2
# ag_global_all_DeepARModel                       2
# ag_global_all_SimpleFeedForwardModel            1
# gemini-1.5-pro_report_True                      1
# Name: Top3, dtype: int64
