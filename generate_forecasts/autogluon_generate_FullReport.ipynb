# %%
from utils_experiment import (
    load_data,
    filter_data_exp_1,
    AutoGluonProcessor,
    fit_predictors_local,
    fit_predictors_global,
    get_model_list,
    create_output_directories,
    process_and_plot_forecasts,
)

# %%
import torch
print("Is cuda available? {}".format(torch.cuda.is_available()))
torch.cuda.get_device_name(torch.cuda.current_device())
# Out:
# Is cuda available? True
# 'Tesla T4'

# %% [markdown]
# ## Experiment 1 Details
#
# Experiment 1 serves as a baseline for comparing the effect of different window lengths for training. The data will be filtered to include only time series that are available in the time period. To investiage the effect of the time series by themselves, the number of covariates is kept constant across all time series and corresponds to the time series fully available from 1986. The specific time periods were chosen with the condition that between each interval, 5 or more new time series were introduced.
#
# | Time Period - 2024     | Maximum number of covariates | Number of covariates used |
# |--------------|:-----:| :-----:|
# | 1986 |   94  |   94  |
# | 1997 |   111  |  94  |
# | 2004 |   133  |   94  |
# | 2007 |   146  |  94  |
# | 2010 |   154  |  94  |
# | 2018 |   159  |  94  |
#
#
# The cut-off dates are set at 4 yearly intervals between 2020 and 2024. Since the minimum training length for a yearly interval is 2 years, 2020 is the earliest cut-off date we can use.

# %%
exp_test_description = "Full_Report"
report_sim_dates = open("/h/kupfersk/cfpr_2025/generate_forecasts/experiment_cutoff_dates.txt", 'r').read().split()

target_categories = [
    'Bakery and cereal products (excluding baby food)',
     'Dairy products and eggs',
     'Fish, seafood and other marine products',
     'Food purchased from restaurants',
     'Food',
     'Fruit, fruit preparations and nuts',
     'Meat',
     'Other food products and non-alcoholic beverages',
     'Vegetables and vegetable preparations'
]

target_categories = [f"food_cpi: {col}" for col in target_categories]

start_year = 1986
random_seed = 42

print("Target Categories:\n" + '\n'.join(target_categories))
print("Report Simulation Dates:\n" + '\n'.join(report_sim_dates))
# Out:
# Target Categories:
# food_cpi: Bakery and cereal products (excluding baby food)
# food_cpi: Dairy products and eggs
# food_cpi: Fish, seafood and other marine products
# food_cpi: Food purchased from restaurants
# food_cpi: Food
# food_cpi: Fruit, fruit preparations and nuts
# food_cpi: Meat
# food_cpi: Other food products and non-alcoholic beverages
# food_cpi: Vegetables and vegetable preparations
# Report Simulation Dates:
# 2018-07-01
# 2019-07-01
# 2020-07-01
# 2021-07-01
# 2022-07-01
# 2023-07-01

# %% [markdown]
# ## Load data
#
# `all_data`: dataframe with all the food cpi variables and all the covariates from 1986 to 2024.\
# `foodprice_df`: dataframe with only the food cpi variables from 1986 to 2024.\
# `target_categories`: list of the names of the food cpi variables.\
# `all_covariates`: dataframe with all the covariates from 1986 to 2024.

# %%
file_path = "/h/kupfersk/cfpr_2025/data/processed_data/all_data_processed.csv"
all_data, foodprice_df, target_categories, all_covariates = load_data(target_categories, file_path)

# %%
foodprice_df
# Out:
#             food_cpi: Bakery and cereal products (excluding baby food)  \
# 1986-01-01                                               69.3
# 1986-02-01                                               70.3
# 1986-03-01                                               70.6
# 1986-04-01                                               71.3
# 1986-05-01                                               71.2
# ...                                                       ...
# 2024-05-01                                              198.8
# 2024-06-01                                              198.2
# 2024-07-01                                              199.1
# 2024-08-01                                              198.4
# 2024-09-01                                              196.4
#
#             food_cpi: Dairy products and eggs  \
# 1986-01-01                               70.9
# 1986-02-01                               70.8
# 1986-03-01                               71.1
# 1986-04-01                               71.0
# 1986-05-01                               71.4
# ...                                       ...
# 2024-05-01                              171.0
# 2024-06-01                              173.7
# 2024-07-01                              174.4
# 2024-08-01                              174.4
# 2024-09-01                              174.2
#
#             food_cpi: Fish, seafood and other marine products  \
# 1986-01-01                                               60.6
# 1986-02-01                                               61.3
# 1986-03-01                                               61.3
# 1986-04-01                                               61.4
# 1986-05-01                                               61.9
# ...                                                       ...
# 2024-05-01                                              160.8
# 2024-06-01                                              161.0
# 2024-07-01                                              162.1
# 2024-08-01                                              162.1
# 2024-09-01                                              162.5
#
#             food_cpi: Food purchased from restaurants  food_cpi: Food  \
# 1986-01-01                                       59.1            67.3
# 1986-02-01                                       59.1            66.9
# 1986-03-01                                       59.3            67.0
# 1986-04-01                                       59.7            67.7
# 1986-05-01                                       59.9            68.2
# ...                                               ...             ...
# 2024-05-01                                      194.2           189.0
# 2024-06-01                                      195.0           190.0
# 2024-07-01                                      195.3           190.5
# 2024-08-01                                      195.5           190.3
# 2024-09-01                                      196.0           190.3
#
#             food_cpi: Fruit, fruit preparations and nuts  food_cpi: Meat  \
# 1986-01-01                                          76.0            65.1
# 1986-02-01                                          77.6            64.2
# 1986-03-01                                          79.2            64.2
# 1986-04-01                                          82.2            63.6
# 1986-05-01                                          83.5            64.0
# ...                                                  ...             ...
# 2024-05-01                                         168.8           210.2
# 2024-06-01                                         171.0           211.3
# 2024-07-01                                         168.8           212.8
# 2024-08-01                                         168.3           212.5
# 2024-09-01                                         168.9           214.0
#
#             food_cpi: Other food products and non-alcoholic beverages  \
# 1986-01-01                                               77.5
# 1986-02-01                                               78.1
# 1986-03-01                                               78.6
# 1986-04-01                                               79.5
# 1986-05-01                                               79.8
# ...                                                       ...
# 2024-05-01                                              177.9
# 2024-06-01                                              178.5
# 2024-07-01                                              177.9
# 2024-08-01                                              179.5
# 2024-09-01                                              179.1
#
#             food_cpi: Vegetables and vegetable preparations
# 1986-01-01                                             76.0
# 1986-02-01                                             68.4
# 1986-03-01                                             66.2
# 1986-04-01                                             71.1
# 1986-05-01                                             75.3
# ...                                                     ...
# 2024-05-01                                            189.7
# 2024-06-01                                            190.2
# 2024-07-01                                            194.7
# 2024-08-01                                            189.8
# 2024-09-01                                            188.2
#
# [465 rows x 9 columns]

# %%
all_data = filter_data_exp_1(all_data, start_year)
processor = AutoGluonProcessor(all_data, target_categories)

# %% [markdown]
# # Experiment List
#
# | AutoGluon Model \ Experiment      | local | global | global + covariates |
# |--------------|:-----:| :-----: | :-----: |
# | NaiveModel |   x  |   |  |
# | SeasonalNaiveModel|   x    |  |  |
# | AutoARIMAModel|   x   |  |  |
# | AutoETSModel|  x  |    |  |
# | DeepARModel|  x   | x |  x |
# | DLinearModel| x   | x |  x|
# | PatchTSTModel|  x   | x | x |
# |SimpleFeedForwardModel|  x   | x | x |
# | TemporalFusionTransformerModel| x  | x | x |
# | DirectTabularModel| x   | x | x |
# |RecursiveTabularModel|  x   | x | x |
# |ChronosModel|  x   | x | x |
#
# x - model type supported

# %% [markdown]
# ## Main experiment loop - local models
#
# 4 main loops:
# - The first loop goes through the list of years at which we want the time window to start, filters out the covariates that are not fully available from 1986.
# - The second loop goes though each of the 12 Autogluon models.
# - The third loop goes through each of the yearly cut-off dates to trim the training data.
# - The fourth loop goes through each of the 9 food categories, gets the training data in the AutoGluon format for local models and plot each prediction period againt the actual values.

# %%
EXP_BASE = "ag_local"
EXP_MODEL_LIST = get_model_list(EXP_BASE)


for model_type in EXP_MODEL_LIST:
    EXPERIMENT_NAME = f"{EXP_BASE}_{model_type}"
    
#     if 'Chronos' not in model_type:
#         continue

    for cutoff_date in report_sim_dates:
        forecast_output_dir, plot_output_dir, training_output_dir, model_dir = (
            create_output_directories(
                exp_test_description,
                start_year,
                EXPERIMENT_NAME,
                cutoff_date,
                random_seed
            )
        )

        for category in target_categories:
            train_data = processor.get_autogluon_local_df(category, cutoff_date)
            predictor = fit_predictors_local(model_type, model_dir, train_data, category, random_seed)
            process_and_plot_forecasts(
                predictor,
                train_data,
                category,
                training_output_dir,
                forecast_output_dir,
                plot_output_dir,
                foodprice_df,
                cutoff_date
            )
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="./output/Full_Report/ag_local_NaiveModel/random_seed_42/2018-07-01/model_files//food_cpi: Bakery and cereal products (excluding baby food)/"
# Beginning AutoGluon training... Time limit = 1800s
# AutoGluon will save models to './output/Full_Report/ag_local_NaiveModel/random_seed_42/2018-07-01/model_files//food_cpi: Bakery and cereal products (excluding baby food)/'
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.8.20
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #147~18.04.1-Ubuntu SMP Sat Oct 15 13:10:18 UTC 2022
# CPU Count:          32
# GPU Count:          1
# Memory Avail:       138.84 GB / 188.59 GB (73.6%)
# Disk Space Avail:   17964.05 GB / 249006.62 GB (7.2%)
# ===================================================
#
# Fitting with arguments:
# {'enable_ensemble': True,
#  'eval_metric': MAPE,
#  'hyperparameters': {'NaiveModel': {}},
#  'known_covariates_names': [],
#  'num_val_windows': 1,
#  'prediction_length': 18,
#  'quantile_levels': [0.01, 0.05, 0.1, 0.25, 0.75, 0.9, 0.95, 0.99],
#  'random_seed': 42,
#  'refit_every_n_windows': 1,
#  'refit_full': False,
#  'skip_model_selection': False,
#  'target': 'target',
#  'time_limit': 1800,
#  'verbosity': 2}
#
# Inferred time series frequency: 'MS'
# Provided train_data has 391 rows, 1 time series. Median time series length is 391 (min=391, max=391).
#
# Provided data contains following columns:
# 	target: 'target'
#
# AutoGluon will gauge predictive performance using evaluation metric: 'MAPE'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# ===================================================
#
# Starting training. Start time is 2024-10-26 14:58:04
# Models that will be trained: ['Naive']
# Training timeseries model Naive. Training for up to 1800.0s of the 1800.0s of remaining time.
# NaiveModel
# Fatal Python error: init_import_size: Failed to import the site module
# Python runtime state: initialized
# Fatal Python error: Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site.py", line 589, in <module>
#     main()
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site.py", line 575, in main
#     known_paths = addusersitepackages(known_paths)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site.py", line 325, in addusersitepackages
#     addsitedir(user_site, known_paths)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site.py", line 217, in addsitedir
#     addpackage(sitedir, name, known_paths)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site.py", line 168, in addpackage
#     f = io.TextIOWrapper(io.open_code(fullname))
# KeyboardInterrupt
# init_import_size: Failed to import the site module
# Python runtime state: initialized
# Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 185, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/memory.py", line 28, in <module>
#     from . import hashing
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 934, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1032, in get_data
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 185, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/memory.py", line 12, in <module>
#     import asyncio
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/asyncio/__init__.py", line 8, in <module>
#     from .base_events import *
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/asyncio/base_events.py", line 44, in <module>
#     from . import sslproto
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/asyncio/sslproto.py", line 11, in <module>
#     from . import transports
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 934, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1032, in get_data
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 185, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/memory.py", line 28, in <module>
#     from . import hashing
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/hashing.py", line 10, in <module>
#     import pickle
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 934, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1032, in get_data
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 185, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/memory.py", line 12, in <module>
#     import asyncio
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/asyncio/__init__.py", line 44, in <module>
#     from .unix_events import *  # pragma: no cover
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/asyncio/unix_events.py", line 17, in <module>
#     from . import base_subprocess
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 934, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1032, in get_data
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 185, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/memory.py", line 29, in <module>
#     from ._store_backends import CacheWarning  # noqa
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/_store_backends.py", line 17, in <module>
#     from .backports import concurrency_safe_rename
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/backports.py", line 112, in <module>
#     import numpy as np
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/numpy/__init__.py", line 148, in <module>
#     from . import _distributor_init
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/numpy/_distributor_init.py", line 13, in <module>
#     import mkl
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/mkl/__init__.py", line 49, in <module>
#     from . import _mklinit
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 185, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/memory.py", line 12, in <module>
#     import asyncio
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/asyncio/__init__.py", line 8, in <module>
#     from .base_events import *
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/asyncio/base_events.py", line 34, in <module>
#     import ssl
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/ssl.py", line 98, in <module>
#     import _ssl             # if we can't import it, let the error propagate
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 185, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/memory.py", line 29, in <module>
#     from ._store_backends import CacheWarning  # noqa
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/_store_backends.py", line 17, in <module>
#     from .backports import concurrency_safe_rename
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/backports.py", line 112, in <module>
#     import numpy as np
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/numpy/__init__.py", line 150, in <module>
#     from . import core
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/numpy/core/__init__.py", line 89, in <module>
#     from . import einsumfunc
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 934, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1032, in get_data
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 185, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/memory.py", line 12, in <module>
#     import asyncio
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/asyncio/__init__.py", line 8, in <module>
#     from .base_events import *
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/asyncio/base_events.py", line 18, in <module>
#     import concurrent.futures
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/concurrent/futures/__init__.py", line 8, in <module>
#     from concurrent.futures._base import (FIRST_COMPLETED,
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/concurrent/futures/_base.py", line 7, in <module>
#     import logging
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/logging/__init__.py", line 28, in <module>
#     from string import Template
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 934, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1032, in get_data
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 185, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/memory.py", line 29, in <module>
#     from ._store_backends import CacheWarning  # noqa
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/_store_backends.py", line 17, in <module>
#     from .backports import concurrency_safe_rename
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/backports.py", line 9, in <module>
#     from multiprocessing import util
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/multiprocessing/__init__.py", line 16, in <module>
#     from . import context
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/multiprocessing/context.py", line 30, in <module>
#     class BaseContext(object):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/multiprocessing/context.py", line 110, in BaseContext
#     def SimpleQueue(self):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 185, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/memory.py", line 28, in <module>
#     from . import hashing
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/hashing.py", line 11, in <module>
#     import hashlib
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/hashlib.py", line 251, in <module>
#     globals()[__func_name] = __get_hash(__func_name)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/hashlib.py", line 131, in __get_openssl_constructor
#     f()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site.py", line 589, in <module>
#     main()
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site.py", line 576, in main
#     known_paths = addsitepackages(known_paths)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site.py", line 359, in addsitepackages
#     addsitedir(sitedir, known_paths)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site.py", line 217, in addsitedir
#     addpackage(sitedir, name, known_paths)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site.py", line 168, in addpackage
#     f = io.TextIOWrapper(io.open_code(fullname))
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 185, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/memory.py", line 19, in <module>
#     import pydoc
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/pydoc.py", line 366, in <module>
#     class Doc:
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/pydoc.py", line 396, in Doc
#     def getdocloc(self, object, basedir=sysconfig.get_path('stdlib')):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/sysconfig.py", line 534, in get_path
#     return get_paths(scheme, vars, expand)[name]
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/sysconfig.py", line 524, in get_paths
#     return _expand_vars(scheme, vars)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/sysconfig.py", line 177, in _expand_vars
#     _extend_dict(vars, get_config_vars())
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/sysconfig.py", line 572, in get_config_vars
#     _init_posix(_CONFIG_VARS)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/sysconfig.py", line 440, in _init_posix
#     _temp = __import__(name, globals(), locals(), ['build_time_vars'], 0)
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 934, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1032, in get_data
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 185, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/memory.py", line 29, in <module>
#     from ._store_backends import CacheWarning  # noqa
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/_store_backends.py", line 17, in <module>
#     from .backports import concurrency_safe_rename
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/joblib/backports.py", line 112, in <module>
#     import numpy as np
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/numpy/__init__.py", line 150, in <module>
#     from . import core
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/numpy/core/__init__.py", line 22, in <module>
#     from . import multiarray
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/numpy/core/multiarray.py", line 1022, in <module>
#     def unravel_index(indices, shape=None, order=None):
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/numpy/core/overrides.py", line 224, in decorator
#     return array_function_dispatch(
#   File "/h/kupfersk/cfpr_2025/cfpr_2025/miniconda3/envs/cfpr_2025_py3.8/lib/python3.8/site-packages/numpy/core/overrides.py", line 197, in decorator
#     source_object = compile(
# KeyboardInterrupt
# KeyboardInterrupt

# %%
EXP_MODEL_LIST
# Out:
# ['NaiveModel',
#  'SeasonalNaiveModel',
#  'AutoARIMAModel',
#  'AutoETSModel',
#  'DeepARModel',
#  'DLinearModel',
#  'PatchTSTModel',
#  'SimpleFeedForwardModel',
#  'TemporalFusionTransformerModel',
#  'ChronosModel']

# %% [markdown]
# # Main experiment loop - global models
#
# 5 main loops:
# - The first loop goes through the list of years at which we want the time window to start, filters out the covariates that are not fully available from 1986.
# - The second loop goes though the two experiment base (global and global+covariates)
# - The third loop goes though 8 Autogluon models, excluding all statistical models (Naive, SeasonalNaive, AutoArima, AutoETS).
# - The fourth loop goes through each of the yearly cut-off dates to trim the training data.
# - The fifth loop goes through each of the 9 food categories, gets the training data in the AutoGluon format depending on the experiment base and plot each prediction period againt the actual values.

# %%
EXP_BASE_LIST_GLOBAL = ["ag_global_all", "ag_global_cpi_with_covariates"]




for EXP_BASE in EXP_BASE_LIST_GLOBAL:
    EXP_MODEL_LIST = get_model_list(EXP_BASE)
    print(EXP_MODEL_LIST)

    for model_type in EXP_MODEL_LIST:
        print(model_type)
        
        
        EXPERIMENT_NAME = f"{EXP_BASE}_{model_type}"

        for cutoff_date in report_sim_dates:
            forecast_output_dir, plot_output_dir, training_output_dir, model_dir = (
                create_output_directories(
                    exp_test_description,
                    start_year,
                    EXPERIMENT_NAME,
                    cutoff_date,
                    random_seed
                )
            )

            if "_covariates" in EXP_BASE:
                train_data = processor.get_autogluon_global_with_covariates_df(
                    cutoff_date
                )
            else:
                train_data = processor.get_autogluon_global_df(cutoff_date)

            predictor = fit_predictors_global(model_type, model_dir, train_data, random_seed)

            for category in target_categories:
                process_and_plot_forecasts(
                    predictor,
                    train_data,
                    category,
                    training_output_dir,
                    forecast_output_dir,
                    plot_output_dir,
                    foodprice_df,
                    cutoff_date
                )
# Out:
# ['TemporalFusionTransformerModel']
# TemporalFusionTransformerModel
# Beginning AutoGluon training... Time limit = 1800s
# AutoGluon will save models to './output/Full_Report/ag_global_cpi_with_covariates_TemporalFusionTransformerModel/random_seed_42/2023-07-01/model_files/'
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.8.20
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #147~18.04.1-Ubuntu SMP Sat Oct 15 13:10:18 UTC 2022
# CPU Count:          32
# GPU Count:          1
# Memory Avail:       165.76 GB / 188.59 GB (87.9%)
# Disk Space Avail:   17380.57 GB / 249006.62 GB (7.0%)
# ===================================================
#
# Fitting with arguments:
# {'enable_ensemble': True,
#  'eval_metric': MAPE,
#  'excluded_model_types': ['DirectTabular', 'RecursiveTabular'],
#  'hyperparameters': {'TemporalFusionTransformerModel': {}},
#  'known_covariates_names': [],
#  'num_val_windows': 3,
#  'prediction_length': 18,
#  'quantile_levels': [0.01, 0.05, 0.1, 0.25, 0.75, 0.9, 0.95, 0.99],
#  'random_seed': 42,
#  'refit_every_n_windows': 1,
#  'refit_full': False,
#  'skip_model_selection': False,
#  'target': 'target',
#  'time_limit': 1800,
#  'verbosity': 2}
#
# Inferred time series frequency: 'MS'
# Provided train_data has 4059 rows, 9 time series. Median time series length is 451 (min=451, max=451).
#
# Provided data contains following columns:
# 	target: 'target'
# TemporalFusionTransformerModel
# 	past_covariates:
# 		categorical:        []
# 		continuous (float): ['exogenous_swe_nl: SWE', 'exogenous_swe_sj: SWE', 'exogenous_swe_sr: SWE', 'exogenous_swe_tl: SWE', 'exogenous_po...rtainty Index', 'exogenous_ap... APU000072610', ...]
#
# To learn how to fix incorrectly inferred types, please see documentation for TimeSeriesPredictor.fit
#
# AutoGluon will gauge predictive performance using evaluation metric: 'MAPE'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# ===================================================
#
# Starting training. Start time is 2024-10-18 11:05:05
# Excluded model types: ['DirectTabular', 'RecursiveTabular']
# Models that will be trained: ['TemporalFusionTransformer']
# Training timeseries model TemporalFusionTransformer. Training for up to 1799.8s of the 1799.8s of remaining time.
# 	-0.0337       = Validation score (-MAPE)
# 	416.62  s     = Training runtime
# 	0.14    s     = Validation (prediction) runtime
# Not fitting ensemble as only 1 model was trained.
# Training complete. Models trained: ['TemporalFusionTransformer']
# Total runtime: 416.83 s
# Best model: TemporalFusionTransformer
# Best model score: -0.0337
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# ****************** Summary of fit() ******************
# Estimated performance of each model:
#                        model  score_val  pred_time_val  fit_time_marginal  \
# 0  TemporalFusionTransformer  -0.033749       0.141444         416.624144
#
#    fit_order
# 0          1
# Number of models trained: 1
# Types of models trained:
# {'MultiWindowBacktestingModel'}
# ****************** End of fit() summary ******************
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# ****************** Summary of fit() ******************
# Estimated performance of each model:
#                        model  score_val  pred_time_val  fit_time_marginal  \
# 0  TemporalFusionTransformer  -0.033749       0.141444         416.624144
#
#    fit_order
# 0          1
# Number of models trained: 1
# Types of models trained:
# {'MultiWindowBacktestingModel'}
# ****************** End of fit() summary ******************
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# ****************** Summary of fit() ******************
# Estimated performance of each model:
#                        model  score_val  pred_time_val  fit_time_marginal  \
# 0  TemporalFusionTransformer  -0.033749       0.141444         416.624144
#
#    fit_order
# 0          1
# Number of models trained: 1
# Types of models trained:
# {'MultiWindowBacktestingModel'}
# ****************** End of fit() summary ******************
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# ****************** Summary of fit() ******************
# Estimated performance of each model:
#                        model  score_val  pred_time_val  fit_time_marginal  \
# 0  TemporalFusionTransformer  -0.033749       0.141444         416.624144
#
#    fit_order
# 0          1
# Number of models trained: 1
# Types of models trained:
# {'MultiWindowBacktestingModel'}
# ****************** End of fit() summary ******************
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# ****************** Summary of fit() ******************
# Estimated performance of each model:
#                        model  score_val  pred_time_val  fit_time_marginal  \
# 0  TemporalFusionTransformer  -0.033749       0.141444         416.624144
#
#    fit_order
# 0          1
# Number of models trained: 1
# Types of models trained:
# {'MultiWindowBacktestingModel'}
# ****************** End of fit() summary ******************
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# ****************** Summary of fit() ******************
# Estimated performance of each model:
#                        model  score_val  pred_time_val  fit_time_marginal  \
# 0  TemporalFusionTransformer  -0.033749       0.141444         416.624144
#
#    fit_order
# 0          1
# Number of models trained: 1
# Types of models trained:
# {'MultiWindowBacktestingModel'}
# ****************** End of fit() summary ******************
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# ****************** Summary of fit() ******************
# Estimated performance of each model:
#                        model  score_val  pred_time_val  fit_time_marginal  \
# 0  TemporalFusionTransformer  -0.033749       0.141444         416.624144
#
#    fit_order
# 0          1
# Number of models trained: 1
# Types of models trained:
# {'MultiWindowBacktestingModel'}
# ****************** End of fit() summary ******************
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# ****************** Summary of fit() ******************
# Estimated performance of each model:
#                        model  score_val  pred_time_val  fit_time_marginal  \
# 0  TemporalFusionTransformer  -0.033749       0.141444         416.624144
#
#    fit_order
# 0          1
# Number of models trained: 1
# Types of models trained:
# {'MultiWindowBacktestingModel'}
# ****************** End of fit() summary ******************
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer
# ****************** Summary of fit() ******************
# Estimated performance of each model:
#                        model  score_val  pred_time_val  fit_time_marginal  \
# 0  TemporalFusionTransformer  -0.033749       0.141444         416.624144
#
#    fit_order
# 0          1
# Number of models trained: 1
# Types of models trained:
# {'MultiWindowBacktestingModel'}
# ****************** End of fit() summary ******************
# Model not specified in predict, will default to the model with the best validation score: TemporalFusionTransformer

# %%
predictor.fit_summary()

# %%
train_data
