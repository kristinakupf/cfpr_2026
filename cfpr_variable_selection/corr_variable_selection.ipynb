# %% [markdown]
# # Exogenous Variable Correlational Analysis
#
# This notebook takes the all_df created in the data_processing notebook and breaks it into a dictionary that is then passed into the full_corr_selection function. This function creates a lagged target and an exogenous variable df which are concatenated and correlated. This is then passed through a threshold and only the variables satifying the threshold are returned.

# %%
import pandas as pd
import numpy as np
import os
import glob
import sys
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime

# allowing for switch from interactive env to non-interactive
if "__file__" in globals():
    base_path = os.path.dirname(__file__)
else:
    base_path = os.getcwd()

# Pulling the data functions from the other dir
data_functions_path = os.path.abspath(
    os.path.join(base_path, "../cfpr_data_processing")
)
sys.path.append(data_functions_path)

import importlib
import data_functions

importlib.reload(data_functions)
from data_functions import split_dataframe

import corr_var_functions

importlib.reload(corr_var_functions)
from corr_var_functions import *

raw_path = "../data/raw_data/"
processed_path = "../data/processed_data/"
data_utils_path = "../data/utils_data/"
curated_path = "../data/curated_data/"

# %%
# This list includes the all_data dfs and datasets that were collected in the initial sweep,
# but have data that ends early and/or datetime frequencies that are not monthly
ignore_list = open(data_utils_path + "file_ignore_list.txt", "r").read().split()

# %% [markdown]
# ### Read in data

# %%
all_df = pd.read_csv(processed_path + "data_pool.csv", index_col=0)
all_df.index = pd.to_datetime(all_df.index)

all_dict = split_dataframe(all_df)

# %% [markdown]
# ### Running variable selection and correlation

# %% [markdown]
# **Available Parameters:**
#
# * **dict:** the dictionary holding all of the variable dataframes
# * **target_name:** the name of the df that will be the target (ie 'food_cpi: Meat')
# * **start:** date to start range (str)
# * **end:** date to end range (str)
# * **ignore:** a list of df titles you want ignored from the correlation (ie 'food_cpi: Food') (auto set to None)
# * **thresh:** the correlation coefficient threshold (ie 0.6)
# * **select_unique:** the number of best lags to include in the final corr_selection (auto set to 1, just shows the best lag for the associated variable/correlation)
# * **freq:** the datetime frequency of the data (auto set to 'MS')
# * **lag_start:** At what month will the future lags start
# * **lag_end:** At what month will the future lags end
# * **interpolate_cutoff:** defines whether or not you want to use a hard cuttoff date range or a soft cutoff date range (auto set to False - hard cutoff)
# * **log:** what log type to use (None, log, log10, log2)
# * **scaler:** what scaler to use (None, ss, mm)

# %%
start_range = "1986-01-01"
end_range = "2024-01-01"

# %%
targ_names = ['food_cpi_food',
 'food_cpi_meat',
 'food_cpi_fish',
 'food_cpi_dairy',
 'food_cpi_bakery',
 'food_cpi_fruit',
 'food_cpi_vegetables',
 'food_cpi_other',
 'food_cpi_restaurants']

ig = ["food_cpi"]

corr_selection = [[] for _ in targ_names]
selects = [[] for _ in targ_names]

for i in range(len(targ_names)):
    corr_selection[i], selects[i] = full_corr_selection(
        all_dict,
        targ_names[i],
        start_range,
        end_range,
        thresh=0.0,
        log=None,
        scaler='ss',
        freq='MS',
        interpolate_cutoff=False,
        ignore=ig,
        lag_start=1,
    )
# Out:
# scaling
#
# Correlation Summary for food_cpi_food
#
# Threshold: 0.0
# Log: None
# Scaler: ss
# Date Range: 1986-01-01 to 2024-01-01
# Cutoff Interpolated: False
# Number of exogenous regressors considered: 37
# Number of exogenous regressors above threshold: 29
#
#          Target Lag          Exo Variable      Corr
# 0    Lagged_1_Month           cwur0000sa0  0.988692
# 1    Lagged_7_Month                  fmpi  0.986118
# 2    Lagged_8_Month                 impmx  0.983109
# 3    Lagged_7_Month       pcu482111482111  0.981784
# 4    Lagged_3_Month       pcu324191324191  0.980160
# 5    Lagged_1_Month       pcu333132333132  0.967558
# 6    Lagged_1_Month          apu000072610  0.965797
# 7   Lagged_11_Month            rmpi_total  0.963280
# 8    Lagged_8_Month            energy_cpi  0.960349
# 9   Lagged_16_Month                 impch  0.950420
# 10  Lagged_10_Month            fppi_total  0.944577
# 11  Lagged_24_Month            canola_oil  0.940083
# 12   Lagged_8_Month           pcu32533253  0.917218
# 13   Lagged_1_Month                paynsa  0.909612
# 14   Lagged_8_Month                 impca  0.891011
# 15   Lagged_9_Month       pcu325311325311  0.872176
# 16   Lagged_8_Month        commodity_food  0.846841
# 17   Lagged_1_Month       milk_sold_total  0.825296
# 18   Lagged_8_Month  commodity_fertilizer  0.764742
# 19  Lagged_11_Month               wtisplc  0.722790
# 20   Lagged_1_Month    policy_uncertainty  0.708880
# 21  Lagged_24_Month            pdsi_total  0.052390
# 22  Lagged_24_Month         recprousm156n  0.039682
# 23  Lagged_24_Month             unratensa  0.036221
# 24   Lagged_7_Month             swe_total -0.009763
# 25   Lagged_1_Month                excaus -0.188784
# 26   Lagged_1_Month                  enso -0.214054
# 27   Lagged_1_Month       work_stop_total -0.357095
# 28   Lagged_1_Month       irltlt01cam156n -0.865318
# scaling
#
# Correlation Summary for food_cpi_meat
#
# Threshold: 0.0
# Log: None
# Scaler: ss
# Date Range: 1986-01-01 to 2024-01-01
# Cutoff Interpolated: False
# Number of exogenous regressors considered: 37
# Number of exogenous regressors above threshold: 29
#
#          Target Lag          Exo Variable      Corr
# 0    Lagged_9_Month       pcu482111482111  0.974838
# 1    Lagged_2_Month                  fmpi  0.974774
# 2   Lagged_10_Month                 impmx  0.974097
# 3    Lagged_1_Month           cwur0000sa0  0.970094
# 4    Lagged_1_Month       pcu324191324191  0.964004
# 5   Lagged_24_Month            canola_oil  0.951538
# 6    Lagged_3_Month            rmpi_total  0.950042
# 7    Lagged_2_Month            fppi_total  0.949636
# 8    Lagged_1_Month          apu000072610  0.949302
# 9    Lagged_1_Month       pcu333132333132  0.941508
# 10   Lagged_3_Month            energy_cpi  0.938117
# 11  Lagged_15_Month                 impch  0.935667
# 12   Lagged_7_Month           pcu32533253  0.890643
# 13   Lagged_1_Month                paynsa  0.890549
# 14   Lagged_3_Month                 impca  0.858912
# 15   Lagged_1_Month       milk_sold_total  0.850976
# 16   Lagged_9_Month       pcu325311325311  0.844126
# 17   Lagged_6_Month        commodity_food  0.813052
# 18  Lagged_20_Month    policy_uncertainty  0.729334
# 19   Lagged_3_Month  commodity_fertilizer  0.727366
# 20  Lagged_12_Month               wtisplc  0.673910
# 21  Lagged_24_Month            pdsi_total  0.035430
# 22  Lagged_24_Month             unratensa  0.010409
# 23  Lagged_24_Month         recprousm156n -0.002242
# 24   Lagged_7_Month             swe_total -0.037548
# 25   Lagged_1_Month                excaus -0.139324
# 26   Lagged_1_Month                  enso -0.188186
# 27   Lagged_1_Month       work_stop_total -0.327732
# 28   Lagged_1_Month       irltlt01cam156n -0.836570
# scaling
#
# Correlation Summary for food_cpi_fish
#
# Threshold: 0.0
# Log: None
# Scaler: ss
# Date Range: 1986-01-01 to 2024-01-01
# Cutoff Interpolated: False
# Number of exogenous regressors considered: 37
# Number of exogenous regressors above threshold: 29
#
#          Target Lag          Exo Variable      Corr
# 0    Lagged_1_Month           cwur0000sa0  0.969331
# 1   Lagged_10_Month                 impmx  0.962576
# 2   Lagged_24_Month            canola_oil  0.957483
# 3   Lagged_10_Month                  fmpi  0.951388
# 4   Lagged_12_Month       pcu482111482111  0.948801
# 5   Lagged_24_Month            fppi_total  0.943142
# 6    Lagged_5_Month       pcu324191324191  0.935930
# 7    Lagged_1_Month            rmpi_total  0.931121
# 8    Lagged_1_Month          apu000072610  0.923119
# 9    Lagged_1_Month       pcu333132333132  0.921634
# 10   Lagged_1_Month                paynsa  0.918792
# 11   Lagged_1_Month            energy_cpi  0.916389
# 12  Lagged_22_Month                 impch  0.915866
# 13   Lagged_9_Month           pcu32533253  0.863895
# 14   Lagged_2_Month                 impca  0.853722
# 15   Lagged_1_Month       milk_sold_total  0.849795
# 16  Lagged_10_Month       pcu325311325311  0.804286
# 17   Lagged_1_Month        commodity_food  0.768560
# 18  Lagged_24_Month    policy_uncertainty  0.737654
# 19   Lagged_8_Month  commodity_fertilizer  0.689624
# 20  Lagged_11_Month               wtisplc  0.616375
# 21  Lagged_24_Month            pdsi_total  0.089170
# 22   Lagged_7_Month             swe_total  0.006484
# 23  Lagged_24_Month         recprousm156n -0.002084
# 24   Lagged_1_Month                excaus -0.048150
# 25  Lagged_24_Month             unratensa -0.050866
# 26  Lagged_24_Month                  enso -0.177354
# 27   Lagged_1_Month       work_stop_total -0.368410
# 28   Lagged_1_Month       irltlt01cam156n -0.842368
# scaling
#
# Correlation Summary for food_cpi_dairy
#
# Threshold: 0.0
# Log: None
# Scaler: ss
# Date Range: 1986-01-01 to 2024-01-01
# Cutoff Interpolated: False
# Number of exogenous regressors considered: 37
# Number of exogenous regressors above threshold: 29
#
#          Target Lag          Exo Variable      Corr
# 0    Lagged_1_Month       pcu333132333132  0.990034
# 1    Lagged_8_Month           cwur0000sa0  0.988913
# 2    Lagged_1_Month                  fmpi  0.981287
# 3    Lagged_1_Month       pcu324191324191  0.980669
# 4    Lagged_9_Month            energy_cpi  0.979226
# 5    Lagged_9_Month                 impmx  0.972524
# 6    Lagged_1_Month       pcu482111482111  0.970625
# 7    Lagged_1_Month          apu000072610  0.969587
# 8   Lagged_12_Month            rmpi_total  0.954415
# 9   Lagged_16_Month                 impch  0.954025
# 10   Lagged_8_Month                 impca  0.933438
# 11   Lagged_7_Month           pcu32533253  0.932885
# 12   Lagged_3_Month                paynsa  0.909009
# 13   Lagged_1_Month            fppi_total  0.901683
# 14   Lagged_1_Month            canola_oil  0.900513
# 15   Lagged_9_Month       pcu325311325311  0.898703
# 16   Lagged_2_Month        commodity_food  0.884061
# 17   Lagged_9_Month               wtisplc  0.811455
# 18   Lagged_8_Month  commodity_fertilizer  0.808217
# 19   Lagged_1_Month       milk_sold_total  0.750010
# 20   Lagged_1_Month    policy_uncertainty  0.641715
# 21  Lagged_24_Month         recprousm156n  0.096152
# 22  Lagged_24_Month             unratensa  0.090630
# 23  Lagged_24_Month            pdsi_total  0.029687
# 24   Lagged_7_Month             swe_total -0.005086
# 25   Lagged_1_Month                  enso -0.246688
# 26   Lagged_1_Month                excaus -0.308248
# 27   Lagged_1_Month       work_stop_total -0.394114
# 28   Lagged_1_Month       irltlt01cam156n -0.898035
# scaling
#
# Correlation Summary for food_cpi_bakery
#
# Threshold: 0.0
# Log: None
# Scaler: ss
# Date Range: 1986-01-01 to 2024-01-01
# Cutoff Interpolated: False
# Number of exogenous regressors considered: 37
# Number of exogenous regressors above threshold: 29
#
#          Target Lag          Exo Variable      Corr
# 0    Lagged_7_Month                  fmpi  0.992843
# 1    Lagged_5_Month       pcu324191324191  0.990310
# 2    Lagged_1_Month       pcu333132333132  0.988515
# 3    Lagged_9_Month           cwur0000sa0  0.984560
# 4    Lagged_6_Month       pcu482111482111  0.983433
# 5    Lagged_4_Month          apu000072610  0.979491
# 6    Lagged_9_Month                 impmx  0.975535
# 7   Lagged_11_Month            energy_cpi  0.974568
# 8   Lagged_16_Month            rmpi_total  0.971395
# 9   Lagged_16_Month                 impch  0.963275
# 10   Lagged_9_Month           pcu32533253  0.946489
# 11  Lagged_11_Month            fppi_total  0.931180
# 12   Lagged_1_Month            canola_oil  0.926833
# 13  Lagged_12_Month                 impca  0.911843
# 14  Lagged_10_Month       pcu325311325311  0.910632
# 15   Lagged_9_Month        commodity_food  0.899712
# 16   Lagged_1_Month                paynsa  0.892690
# 17  Lagged_10_Month  commodity_fertilizer  0.814806
# 18  Lagged_12_Month               wtisplc  0.800396
# 19   Lagged_1_Month       milk_sold_total  0.769535
# 20   Lagged_1_Month    policy_uncertainty  0.677847
# 21  Lagged_24_Month             unratensa  0.117960
# 22  Lagged_24_Month         recprousm156n  0.071544
# 23  Lagged_24_Month            pdsi_total  0.041289
# 24   Lagged_7_Month             swe_total -0.004572
# 25   Lagged_1_Month                  enso -0.223165
# 26   Lagged_1_Month                excaus -0.284156
# 27   Lagged_1_Month       work_stop_total -0.364574
# 28   Lagged_1_Month       irltlt01cam156n -0.881708
# scaling
#
# Correlation Summary for food_cpi_fruit
#
# Threshold: 0.0
# Log: None
# Scaler: ss
# Date Range: 1986-01-01 to 2024-01-01
# Cutoff Interpolated: False
# Number of exogenous regressors considered: 37
# Number of exogenous regressors above threshold: 29
#
#          Target Lag          Exo Variable      Corr
# 0    Lagged_9_Month       pcu482111482111  0.968766
# 1    Lagged_9_Month                  fmpi  0.967768
# 2    Lagged_5_Month       pcu324191324191  0.961460
# 3    Lagged_9_Month                 impmx  0.958464
# 4   Lagged_11_Month            fppi_total  0.951405
# 5    Lagged_1_Month           cwur0000sa0  0.949501
# 6    Lagged_1_Month          apu000072610  0.947075
# 7   Lagged_13_Month            rmpi_total  0.943072
# 8   Lagged_24_Month            canola_oil  0.930121
# 9    Lagged_1_Month       pcu333132333132  0.929197
# 10   Lagged_8_Month            energy_cpi  0.927633
# 11  Lagged_19_Month                 impch  0.925033
# 12   Lagged_8_Month           pcu32533253  0.899482
# 13  Lagged_12_Month       pcu325311325311  0.856328
# 14   Lagged_1_Month                paynsa  0.855955
# 15   Lagged_1_Month       milk_sold_total  0.850825
# 16   Lagged_9_Month                 impca  0.836253
# 17  Lagged_11_Month        commodity_food  0.825564
# 18   Lagged_9_Month  commodity_fertilizer  0.750116
# 19   Lagged_9_Month    policy_uncertainty  0.718810
# 20  Lagged_14_Month               wtisplc  0.682197
# 21  Lagged_24_Month             unratensa  0.032066
# 22   Lagged_7_Month         recprousm156n  0.030272
# 23  Lagged_24_Month            pdsi_total  0.018014
# 24   Lagged_3_Month             swe_total -0.060805
# 25   Lagged_1_Month                excaus -0.157663
# 26   Lagged_1_Month                  enso -0.176960
# 27   Lagged_1_Month       work_stop_total -0.280781
# 28   Lagged_1_Month       irltlt01cam156n -0.798526
# scaling
#
# Correlation Summary for food_cpi_vegetables
#
# Threshold: 0.0
# Log: None
# Scaler: ss
# Date Range: 1986-01-01 to 2024-01-01
# Cutoff Interpolated: False
# Number of exogenous regressors considered: 37
# Number of exogenous regressors above threshold: 29
#
#          Target Lag          Exo Variable      Corr
# 0    Lagged_8_Month       pcu482111482111  0.932145
# 1    Lagged_8_Month                 impmx  0.923762
# 2   Lagged_10_Month            fppi_total  0.921974
# 3    Lagged_8_Month                  fmpi  0.918643
# 4    Lagged_3_Month       pcu324191324191  0.918358
# 5   Lagged_24_Month            canola_oil  0.916715
# 6    Lagged_1_Month           cwur0000sa0  0.904975
# 7   Lagged_10_Month            rmpi_total  0.903464
# 8    Lagged_7_Month          apu000072610  0.898996
# 9   Lagged_19_Month                 impch  0.887201
# 10   Lagged_9_Month            energy_cpi  0.878159
# 11   Lagged_1_Month       pcu333132333132  0.870422
# 12  Lagged_11_Month       milk_sold_total  0.868648
# 13   Lagged_8_Month           pcu32533253  0.845773
# 14   Lagged_7_Month                paynsa  0.812828
# 15  Lagged_11_Month       pcu325311325311  0.796387
# 16   Lagged_8_Month                 impca  0.777274
# 17  Lagged_10_Month        commodity_food  0.760610
# 18   Lagged_3_Month    policy_uncertainty  0.744811
# 19   Lagged_8_Month  commodity_fertilizer  0.695752
# 20   Lagged_9_Month               wtisplc  0.607776
# 21  Lagged_24_Month            pdsi_total  0.038282
# 22  Lagged_24_Month         recprousm156n  0.006942
# 23  Lagged_24_Month             unratensa -0.004924
# 24   Lagged_9_Month             swe_total -0.044832
# 25   Lagged_1_Month                excaus -0.079226
# 26   Lagged_1_Month                  enso -0.152841
# 27   Lagged_1_Month       work_stop_total -0.268734
# 28   Lagged_1_Month       irltlt01cam156n -0.739343
# scaling
#
# Correlation Summary for food_cpi_other
#
# Threshold: 0.0
# Log: None
# Scaler: ss
# Date Range: 1986-01-01 to 2024-01-01
# Cutoff Interpolated: False
# Number of exogenous regressors considered: 37
# Number of exogenous regressors above threshold: 29
#
#          Target Lag          Exo Variable      Corr
# 0    Lagged_8_Month                  fmpi  0.988533
# 1    Lagged_1_Month           cwur0000sa0  0.983854
# 2    Lagged_3_Month       pcu324191324191  0.983257
# 3    Lagged_5_Month                 impmx  0.977408
# 4    Lagged_6_Month       pcu482111482111  0.976243
# 5   Lagged_12_Month            rmpi_total  0.972488
# 6    Lagged_1_Month          apu000072610  0.970026
# 7    Lagged_1_Month       pcu333132333132  0.968545
# 8    Lagged_9_Month            energy_cpi  0.963636
# 9   Lagged_11_Month            fppi_total  0.952966
# 10  Lagged_16_Month                 impch  0.942486
# 11   Lagged_9_Month           pcu32533253  0.937342
# 12   Lagged_1_Month            canola_oil  0.924795
# 13  Lagged_10_Month       pcu325311325311  0.900376
# 14   Lagged_5_Month                 impca  0.897673
# 15   Lagged_1_Month                paynsa  0.896841
# 16  Lagged_11_Month        commodity_food  0.876829
# 17  Lagged_10_Month  commodity_fertilizer  0.803523
# 18   Lagged_1_Month       milk_sold_total  0.801827
# 19  Lagged_11_Month               wtisplc  0.750459
# 20  Lagged_24_Month    policy_uncertainty  0.682694
# 21  Lagged_24_Month             unratensa  0.093772
# 22  Lagged_24_Month            pdsi_total  0.066345
# 23  Lagged_24_Month         recprousm156n  0.065543
# 24   Lagged_7_Month             swe_total  0.008448
# 25   Lagged_1_Month                excaus -0.216990
# 26   Lagged_1_Month                  enso -0.230320
# 27   Lagged_1_Month       work_stop_total -0.336757
# 28   Lagged_1_Month       irltlt01cam156n -0.853186
# scaling
#
# Correlation Summary for food_cpi_restaurants
#
# Threshold: 0.0
# Log: None
# Scaler: ss
# Date Range: 1986-01-01 to 2024-01-01
# Cutoff Interpolated: False
# Number of exogenous regressors considered: 37
# Number of exogenous regressors above threshold: 29
#
#          Target Lag          Exo Variable      Corr
# 0    Lagged_1_Month           cwur0000sa0  0.992846
# 1    Lagged_2_Month                 impmx  0.980741
# 2    Lagged_1_Month                  fmpi  0.976754
# 3    Lagged_1_Month       pcu482111482111  0.972154
# 4    Lagged_1_Month       pcu324191324191  0.969675
# 5    Lagged_1_Month       pcu333132333132  0.963627
# 6    Lagged_1_Month          apu000072610  0.957329
# 7    Lagged_2_Month            energy_cpi  0.955980
# 8    Lagged_3_Month            rmpi_total  0.954277
# 9   Lagged_15_Month                 impch  0.945042
# 10  Lagged_24_Month            canola_oil  0.941872
# 11  Lagged_24_Month            fppi_total  0.938035
# 12   Lagged_1_Month                paynsa  0.926794
# 13   Lagged_7_Month           pcu32533253  0.898756
# 14   Lagged_1_Month                 impca  0.898041
# 15   Lagged_9_Month       pcu325311325311  0.847957
# 16   Lagged_1_Month        commodity_food  0.829947
# 17   Lagged_1_Month       milk_sold_total  0.821565
# 18   Lagged_2_Month  commodity_fertilizer  0.740563
# 19   Lagged_1_Month    policy_uncertainty  0.711310
# 20   Lagged_2_Month               wtisplc  0.705259
# 21  Lagged_24_Month            pdsi_total  0.073912
# 22  Lagged_24_Month         recprousm156n  0.039501
# 23   Lagged_7_Month             swe_total  0.015120
# 24  Lagged_24_Month             unratensa -0.000906
# 25   Lagged_1_Month                excaus -0.171019
# 26  Lagged_24_Month                  enso -0.215657
# 27   Lagged_1_Month       work_stop_total -0.385002
# 28   Lagged_1_Month       irltlt01cam156n -0.878561
